# %%
import network

# %%
model_unet = network.UNet()
model_unet.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_1 (InputLayer)           [(None, 1024, 768,   0           []
#                                 8)]
#
#  conv2d (Conv2D)                (None, 1024, 768, 6  4672        ['input_1[0][0]']
#                                 4)
#
#  conv2d_1 (Conv2D)              (None, 1024, 768, 6  36928       ['conv2d[0][0]']
#                                 4)
#
#  max_pooling2d (MaxPooling2D)   (None, 512, 384, 64  0           ['conv2d_1[0][0]']
#                                 )
#
#  conv2d_2 (Conv2D)              (None, 512, 384, 12  73856       ['max_pooling2d[0][0]']
#                                 8)
#
#  conv2d_3 (Conv2D)              (None, 512, 384, 12  147584      ['conv2d_2[0][0]']
#                                 8)
#
# ...

# %%
model_segnet = network.SegNet()
model_segnet.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_2 (InputLayer)           [(None, 1024, 768,   0           []
#                                 8)]
#
#  conv2d_23 (Conv2D)             (None, 1024, 768, 6  4672        ['input_2[0][0]']
#                                 4)
#
#  batch_normalization (BatchNorm  (None, 1024, 768, 6  256        ['conv2d_23[0][0]']
#  alization)                     4)
#
#  conv2d_24 (Conv2D)             (None, 1024, 768, 6  36928       ['batch_normalization[0][0]']
#                                 4)
#
#  batch_normalization_1 (BatchNo  (None, 1024, 768, 6  256        ['conv2d_24[0][0]']
#  rmalization)                   4)
#
#  max_pool2d_with_argmax (MaxPoo  [(None, 512, 384, 6  0          ['batch_normalization_1[0][0]']
#  l2DWithArgmax)                 4),
# ...

# %%
model_segunet = network.SegUNet()
model_segunet.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ...
#  input_3 (InputLayer)           [(None, 1024, 768,   0           []
#                                 8)]
#
#  conv2d_44 (Conv2D)             (None, 1024, 768, 6  4672        ['input_3[0][0]']
#                                 4)
#
#  batch_normalization_20 (BatchN  (None, 1024, 768, 6  256        ['conv2d_44[0][0]']
#  ormalization)                  4)
#
#  conv2d_45 (Conv2D)             (None, 1024, 768, 6  36928       ['batch_normalization_20[0][0]']
#                                 4)
#
#  batch_normalization_21 (BatchN  (None, 1024, 768, 6  256        ['conv2d_45[0][0]']
#  ormalization)                  4)
#
#  max_pool2d_with_argmax_4 (MaxP  [(None, 512, 384, 6  0          ['batch_normalization_21[0][0]']
#  ool2DWithArgmax)               4),
# ...
